# %%
import os
import csv
import json
import re
import multiprocessing as mp
import time
from datetime import datetime
import mysql.connector

total_processors = os.cpu_count()
folder_path = './samples/EdNet-KT2-samples'
output_file = './outputs/kt_json_data.json'
counterFiles = 0

DB_CONFIG = {
    'user': 'root',
    'password': 'force8104',
    'host': 'localhost',
    'database': 'tccunb'
}

def unix_to_mysql_datetime(timestamp):
    ts = int(timestamp) 
    dt = datetime.fromtimestamp(ts)
    return dt.strftime('%Y-%m-%d %H:%M:%S')


def insert_data(record):
    insert_sql = """
        INSERT INTO respostas (respondida_em, tipo_acao, item_id, fonte, resposta_usuario, plataforma, user_id)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
    """
    
    for item in record:
        print(f"Processing item: {item}")
        try:
            conn = mysql.connector.connect(**DB_CONFIG)
            cursor = conn.cursor()
            
            # Extract values from the dictionary in the correct order
            values = (
                item['respondida_em'],
                item['tipo_acao'], 
                item['question_id'],  # Assuming question_id maps to item_id
                item['fonte'],
                item['resposta_usuario'],
                item['plataforma'],
                item['user_id']
            )
            
            cursor.execute(insert_sql, values)
            conn.commit()
            print(f"Successfully inserted record with question_id: {item['question_id']}")
            
        except mysql.connector.Error as err:
            print(f"Error inserting record {item}: {err}")
        except KeyError as err:
            print(f"Missing key in record {item}: {err}")
        finally:
            if 'conn' in locals() and conn.is_connected():
                cursor.close()
                conn.close()

def processar_e_salvar(csv_files):
    result = {
        "name": "EdNet-KT2-samples",
        "exams": []
    }
    for filename in csv_files:

        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            print(filename+" ", end="\n")

    for filename in csv_files:
        user_id_match = re.search(r'u(\d+)\.csv', filename)
        if not user_id_match:
            continue

        user_id = int(user_id_match.group(1))
        file_path = os.path.join(folder_path, filename)
        
        user_exam = []
        #Importante
        #Criar a base de dados mysql sem o innoDb para acelearar a consulta e se livrando de FK OK
        #Modelar a tabela  OK
        #Como vou modelar a tabela, sendo que tenho dois bancos de dados completamente diferentes ??????? Utilizo o conceito de meta_keys e meta_values ?  OK
        #Iniciar processo de paralelização, dividindo o número de colunas por workers que vão trabalhar paralelamente para as duas tabelas OK
        #inserir no banco de dados a partir disso OK

        
        with open(file_path, 'r') as file:
            reader = csv.DictReader(file)            

            for row in reader:
                if row['action_type'] == 'respond' and row['item_id'].startswith('q'):
                    question_id = int(row['item_id'][1:])
                    #row['timestamp']
                    exam_entry = {
                        "question_id": question_id,
                        "resposta_usuario": row['user_answer'] if row['user_answer'] else None,
                        "respondida_em": unix_to_mysql_datetime(1205154) if row['timestamp'] else None,
                        "tipo_acao": row['action_type'] ,
                        "fonte": row['source'] ,
                        "plataforma": row['platform'] ,
                        "user_id": user_id,
                    }
                    
                    user_exam.append(exam_entry)

        #print(user_exam)
        insert_data(user_exam[:])
        
        #if user_exam:
        #    user_info = {
        #        "user_id": user_id,
        #        "user_exam": user_exam
        #    }
        #    result["exams"].append(user_info)
    return result

def process_csv_files(folder_path):
    
    
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} not found")
        return None
    
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    

    totalFiles = 0

    totalFiles += sum(1 for row in csv_files)


    tamanho_grupo = totalFiles // total_processors; 
    if(tamanho_grupo == 0 ):
        tamanho_grupo = 1

    #filename in csv_files
    
    grupos = [
        csv_files[i:i + tamanho_grupo] 
        for i in range(0, len(csv_files), tamanho_grupo)
    ]
    

    inicio = time.time()
    with mp.Pool(processes=total_processors) as pool:
        resultados = pool.map(processar_e_salvar, grupos)    


    

#In the future i gonna use the json to send data to backend, as json mainly. 
def save_json(data, output_file):
    with open(output_file, 'w') as f:
        json.dump(data, f, indent=2)

def main():
    
    data = process_csv_files(folder_path)
    
    if data:
        save_json(data, output_file)
    else:
        print("No data processed")

if __name__ == "__main__":
    main()
# Out:
# u9.csv u6.csv u8.csv u3.csv
#
#
#
# Processing item: {'question_id': 5952, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}Processing item: {'question_id': 4420, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}Processing item: {'question_id': 6267, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
#
#
# Processing item: {'question_id': 5346, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 4420
# Processing item: {'question_id': 266, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}
# Successfully inserted record with question_id: 5346
# Processing item: {'question_id': 4375, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}Successfully inserted record with question_id: 6267Successfully inserted record with question_id: 5952
#
#
# Processing item: {'question_id': 4644, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
# Processing item: {'question_id': 4678, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
# Successfully inserted record with question_id: 266
# Processing item: {'question_id': 377, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}Successfully inserted record with question_id: 4375
#
# Processing item: {'question_id': 4730, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 4678
# Successfully inserted record with question_id: 4644
# Processing item: {'question_id': 5531, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
# Processing item: {'question_id': 3950, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 377
# Processing item: {'question_id': 3638, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}
# Successfully inserted record with question_id: 4730
# Processing item: {'question_id': 4603, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 5531Successfully inserted record with question_id: 3950
#
# Processing item: {'question_id': 206, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}Processing item: {'question_id': 3950, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}Successfully inserted record with question_id: 3638
#
#
# Processing item: {'question_id': 4607, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}
# Successfully inserted record with question_id: 4603
# Processing item: {'question_id': 5575, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 206
# Successfully inserted record with question_id: 3950
# Successfully inserted record with question_id: 4607Processing item: {'question_id': 377, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
# Processing item: {'question_id': 4025, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
#
# Processing item: {'question_id': 6112, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}Successfully inserted record with question_id: 5575
#
# Processing item: {'question_id': 210, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 6112Successfully inserted record with question_id: 377
#
# Processing item: {'question_id': 6037, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 3}Successfully inserted record with question_id: 4025Processing item: {'question_id': 4603, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
#
#
# Processing item: {'question_id': 9641, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 210
# Processing item: {'question_id': 4464, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 6037
# Successfully inserted record with question_id: 4603
# Processing item: {'question_id': 1692, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 3}Successfully inserted record with question_id: 9641Processing item: {'question_id': 4429, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 6}
#
#
# Successfully inserted record with question_id: 4464
# Processing item: {'question_id': 6213, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
# Processing item: {'question_id': 10649, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1692
# Successfully inserted record with question_id: 4429
# Successfully inserted record with question_id: 6213
# Processing item: {'question_id': 6243, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'diagnosis', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 10649
# Processing item: {'question_id': 10649, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 6243Successfully inserted record with question_id: 10649
#
# Processing item: {'question_id': 10039, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 8}Processing item: {'question_id': 10649, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
#
# Successfully inserted record with question_id: 10649
# Processing item: {'question_id': 10032, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10039
# Processing item: {'question_id': 1593, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 10032
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1593
# Processing item: {'question_id': 1368, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1368
# Processing item: {'question_id': 1239, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 8}
# Successfully inserted record with question_id: 1239
# Successfully inserted record with question_id: 1626Processing item: {'question_id': 1354, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 8}
#
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1354
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 1626, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1626
# Processing item: {'question_id': 10029, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10029
# Processing item: {'question_id': 135, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 135
# Processing item: {'question_id': 1713, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1713
# Processing item: {'question_id': 1533, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1533
# Processing item: {'question_id': 10637, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10637
# Processing item: {'question_id': 10635, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10635
# Processing item: {'question_id': 10635, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10635
# Processing item: {'question_id': 10635, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10635
# Processing item: {'question_id': 10635, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10635
# Processing item: {'question_id': 10635, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10635
# Processing item: {'question_id': 10636, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10636
# Processing item: {'question_id': 10027, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10027
# Processing item: {'question_id': 10010, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 10010
# Processing item: {'question_id': 1938, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1938
# Processing item: {'question_id': 1199, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1199
# Processing item: {'question_id': 1737, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1737
# Processing item: {'question_id': 11059, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 11059
# Processing item: {'question_id': 564, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 564
# Processing item: {'question_id': 1509, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1509
# Processing item: {'question_id': 3045, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 3045
# Processing item: {'question_id': 3045, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 3045
# Processing item: {'question_id': 3045, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 3045
# Processing item: {'question_id': 17139, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 17139
# Processing item: {'question_id': 11938, 'resposta_usuario': 'd', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 11938
# Processing item: {'question_id': 11938, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 11938
# Processing item: {'question_id': 11107, 'resposta_usuario': 'b', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 11107
# Processing item: {'question_id': 11107, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 11107
# Processing item: {'question_id': 311, 'resposta_usuario': 'c', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 311
# Processing item: {'question_id': 1689, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 1689
# Processing item: {'question_id': 3432, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 3432
# Processing item: {'question_id': 17270, 'resposta_usuario': 'a', 'respondida_em': '1970-01-14 17:45:54', 'tipo_acao': 'respond', 'fonte': 'tutor', 'plataforma': 'mobile', 'user_id': 9}
# Successfully inserted record with question_id: 17270
# No data processed

# %%
total_processors = os.cpu_count()
print(total_processors)
# Out:
# 12
